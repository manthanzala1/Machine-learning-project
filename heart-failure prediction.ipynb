# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\manth\Downloads\heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# check the number of rows and columns
df.shape
# Out:
# (918, 12)

# %%
# check the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# check the missing values
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# check the duplicated data
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
# data visualization
a = sns.countplot(df['Sex'])
a.bar_label(container = a.containers[0])
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
b = sns.countplot(df['ChestPainType'])
b.bar_label(container = b.containers[0])
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
c = df['RestingECG'].value_counts()

# %%
plt.pie(x = c.values,labels = c.index,autopct = '%.2f%%')
plt.show()

# %%
d = df['ExerciseAngina'].value_counts()
plt.pie(x = d.values,labels = d.index,autopct = '%.2f%%')
plt.show()

# %%
sns.histplot(df['Age'],kde = True,bins = 10)
plt.show()

# %%
sns.histplot(df['RestingBP'],kde = True,bins = 10)
plt.show()

# %%
sns.histplot(df['Cholesterol'],kde = True,bins = 10)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()

# %%
df['newSex'] = la.fit_transform(df['Sex'])

# %%
df['newChestPainType'] = la.fit_transform(df['ChestPainType'])

# %%
df['newRestingECG'] = la.fit_transform(df['RestingECG'])

# %%
df['newExerciseAngina'] = la.fit_transform(df['ExerciseAngina'])

# %%
df['newST_Slope'] = la.fit_transform(df['ST_Slope'])

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  newSex  \
# ...

# %%
# sex = F = 0,m = 1
# ChestPainType = ASY =0,ATA = 1,NAP = 2,TA = 3
# RestingECG = LVH = 0,Normal = 1,ST = 2
# ExerciseAngina = N = 0 ,Y = 1
# ST_Slope = FLAT = 1,UP = 2

# %%
df.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],axis = 1,inplace = True)

# %%
df
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      newSex  newChestPainType  newRestingECG  newExerciseAngina  newST_Slope
# ...

# %%
x = df.drop('HeartDisease',axis = 1)
x
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  newSex  \
# 0     40        140          289          0    172      0.0       1
# 1     49        160          180          0    156      1.0       0
# 2     37        130          283          0     98      0.0       1
# 3     48        138          214          0    108      1.5       0
# 4     54        150          195          0    122      0.0       1
# ..   ...        ...          ...        ...    ...      ...     ...
# 913   45        110          264          0    132      1.2       1
# 914   68        144          193          1    141      3.4       1
# 915   57        130          131          0    115      1.2       1
# 916   57        130          236          0    174      0.0       0
# 917   38        138          175          0    173      0.0       1
#
#      newChestPainType  newRestingECG  newExerciseAngina  newST_Slope
# 0                   1              1                  0            2
# ...

# %%
y = df['HeartDisease']
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn import tree

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
scaler = StandardScaler()

# %%
model = tree.DecisionTreeClassifier()

# %%
pipe = make_pipeline(scaler,model)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
y_pre = pipe.predict(x_test)

# %%
pipe.score(x_test,y_test)
# Out:
# 0.7717391304347826

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pre)
# Out:
# 0.7717391304347826
