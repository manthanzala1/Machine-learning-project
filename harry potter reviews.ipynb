# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\manth\Downloads\harry_potter_reviews.csv")

# %%
df
# Out:
#      user_id user_sex  user_age user_country  rating  \
# 0          0   female        50      Germany     2.5
# 1          1   female        23        Spain     4.0
# 2          2     male        32       France     3.0
# 3          3   female        24       Turkey     4.5
# 4          4   female        40        Spain     5.0
# ..       ...      ...       ...          ...     ...
# 486      486   female        41      Belgium     2.0
# 487      487   female        30       Turkey     4.0
# 488      488   female        33       Greece     4.5
# 489      489     male        28        Spain     4.0
# 490      490   female        34      Austria     5.0
#
#                                                comment favourite_character  \
# 0    "The transitions between scenes were awkward, ...       Severus Snape
# 1     "Severus Snape's role adds an intriguing layer."       Severus Snape
# 2    "The pacing was a bit slow, but the characters...         Ron Weasley
# ...

# %%
# check the number of rows and columns
df.shape
# Out:
# (491, 8)

# %%
# check the data types
df.dtypes
# Out:
# user_id                  int64
# user_sex                object
# user_age                 int64
# user_country            object
# rating                 float64
# comment                 object
# favourite_character     object
# date                    object
# dtype: object

# %%
# check the column name
df.columns
# Out:
# Index(['user_id', 'user_sex', 'user_age', 'user_country', 'rating', 'comment',
#        'favourite_character', 'date'],
#       dtype='object')

# %%
# check the missing value
df.isnull().sum()
# Out:
# user_id                0
# user_sex               0
# user_age               0
# user_country           0
# rating                 0
# comment                0
# favourite_character    0
# date                   0
# dtype: int64

# %%
# check the duplicates value
df.duplicated().sum()
# Out:
# 0

# %%
# data visualizations
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = df['user_sex'].value_counts()

# %%
plt.pie(x = a.values,labels = a.index,autopct = '%.2f%%')
plt.show()

# %%
sns.histplot(df['user_age'],kde = True,bins = 10)
plt.show()

# %%
zala = sns.countplot(df['user_country'])
zala.bar_label(container = zala.containers[0])
plt.xticks(rotation = 80)
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
b = sns.barplot(x = "user_country",y = "rating",data = df)
b.bar_label(container = b.containers[0])
plt.xticks(rotation = 80)
plt.show()

# %%
c = sns.countplot(df['favourite_character'])
c.bar_label(container = c.containers[0])
plt.xticks(rotation = 80)
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cor = df.corr()
sns.heatmap(cor,annot = True)
plt.show()

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df
# Out:
#      user_id user_sex  user_age user_country  rating  \
# 0          0   female        50      Germany     2.5
# 1          1   female        23        Spain     4.0
# 2          2     male        32       France     3.0
# 3          3   female        24       Turkey     4.5
# 4          4   female        40        Spain     5.0
# ..       ...      ...       ...          ...     ...
# 486      486   female        41      Belgium     2.0
# 487      487   female        30       Turkey     4.0
# 488      488   female        33       Greece     4.5
# 489      489     male        28        Spain     4.0
# 490      490   female        34      Austria     5.0
#
#                                                comment favourite_character  \
# 0    "The transitions between scenes were awkward, ...       Severus Snape
# 1     "Severus Snape's role adds an intriguing layer."       Severus Snape
# 2    "The pacing was a bit slow, but the characters...         Ron Weasley
# ...

# %%
sns.lineplot(x = 'year',y = 'rating',data = df)
plt.show()
