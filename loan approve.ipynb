# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\manth\Downloads\Applicant-details.csv")
df
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 0             75722        9657655             76                0
# 1             80185        9259353             37               18
# 2             19865        1509721             66                8
# 3             76700        5867312             43                1
# 4             92992        7223191             44                9
# ...             ...            ...            ...              ...
# 99995          6266         156398             69               10
# 99996         54887        1900932             69               11
# 99997         76821        6395936             66               11
# 99998           861        4505937             52                6
# 99999         15796        4186842             58                9
#
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0             single          rented                     no
# ...

# %%
# check the rows and columns
df.shape
# Out:
# (100000, 13)

# %%
# check the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Applicant_ID                 100000 non-null  int64
#  1   Annual_Income                100000 non-null  int64
#  2   Applicant_Age                100000 non-null  int64
#  3   Work_Experience              100000 non-null  int64
#  4   Marital_Status               100000 non-null  object
#  5   House_Ownership              100000 non-null  object
#  6   Vehicle_Ownership(car)       100000 non-null  object
#  7   Occupation                   100000 non-null  object
#  8   Residence_City               100000 non-null  object
#  9   Residence_State              100000 non-null  object
#  10  Years_in_Current_Employment  100000 non-null  int64
#  11  Years_in_Current_Residence   100000 non-null  int64
# ...

# %%
df.describe()
# Out:
#         Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# count  100000.000000   1.000000e+05  100000.000000    100000.000000
# mean    50000.500000   5.001617e+06      49.995400        10.110750
# std     28867.657797   2.876394e+06      17.056051         5.996007
# min         1.000000   1.031000e+04      21.000000         0.000000
# 25%     25000.750000   2.507092e+06      35.000000         5.000000
# 50%     50000.500000   5.004938e+06      50.000000        10.000000
# 75%     75000.250000   7.477502e+06      65.000000        15.000000
# max    100000.000000   9.999180e+06      79.000000        20.000000
#
#        Years_in_Current_Employment  Years_in_Current_Residence  \
# count                100000.000000               100000.000000
# mean                      6.342990                   11.996020
# std                       3.644942                    1.396826
# min                       0.000000                   10.000000
# ...

# %%
# check the null values
df.isnull().sum()
# Out:
# Applicant_ID                   0
# Annual_Income                  0
# Applicant_Age                  0
# Work_Experience                0
# Marital_Status                 0
# House_Ownership                0
# Vehicle_Ownership(car)         0
# Occupation                     0
# Residence_City                 0
# Residence_State                0
# Years_in_Current_Employment    0
# Years_in_Current_Residence     0
# Loan_Default_Risk              0
# dtype: int64

# %%
# check duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# check the outliers
sns.boxplot(df['Applicant_Age'])
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Annual_Income'])
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Occupation'])
plt.xticks(rotation = 80)
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a = sns.countplot(df['Residence_State'])
a.bar_label(container = a.containers[0])
plt.xticks(rotation = 80)
plt.show()
# Out:
# C:\Users\manth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
b = df['Marital_Status'].value_counts()

# %%
plt.pie(x = b.values,labels = b.index,autopct = '%.2f%%')
plt.show()

# %%
c = df['House_Ownership'].value_counts()

# %%
plt.pie(x = c.values,labels = c.index,autopct = '%.2f%%')
plt.show()

# %%
sns.histplot(df['Applicant_Age'],kde = True,bins = 5)
plt.show()

# %%
d = df['Vehicle_Ownership(car)'].value_counts()

# %%
plt.pie(x = d.values,labels = d.index,autopct = '%.2f%%')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()

# %%
df['new Marital_Status'] = la.fit_transform(df['Marital_Status'])

# %%
df['new House_Ownership'] = la.fit_transform(df['House_Ownership'])

# %%
df['new Vehicle_Ownership(car)'] = la.fit_transform(df['Vehicle_Ownership(car)'])

# %%
df
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 0             75722        9657655             76                0
# 1             80185        9259353             37               18
# 2             19865        1509721             66                8
# 3             76700        5867312             43                1
# 4             92992        7223191             44                9
# ...             ...            ...            ...              ...
# 99995          6266         156398             69               10
# 99996         54887        1900932             69               11
# 99997         76821        6395936             66               11
# 99998           861        4505937             52                6
# 99999         15796        4186842             58                9
#
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 0             single          rented                     no
# ...

# %%
# marital status = married = 0,single = 1
# House_Ownership = norent = 0,owned = 1,rented = 2
# Vehicle_Ownership(car) = no = 0,yes = 1

# %%
df.drop(['Applicant_ID','Marital_Status','House_Ownership','Vehicle_Ownership(car)'],axis = 1,inplace = True)

# %%
df
# Out:
#        Annual_Income  Applicant_Age  Work_Experience              Occupation  \
# 0            9657655             76                0            Psychologist
# 1            9259353             37               18      Petroleum_Engineer
# 2            1509721             66                8                 Drafter
# 3            5867312             43                1    Chartered_Accountant
# 4            7223191             44                9  Air_traffic_controller
# ...              ...            ...              ...                     ...
# 99995         156398             69               10   Technology_specialist
# 99996        1900932             69               11     Mechanical_engineer
# 99997        6395936             66               11                Comedian
# 99998        4505937             52                6      Petroleum_Engineer
# 99999        4186842             58                9               Librarian
#
# ...

# %%
x = df.drop('Loan_Default_Risk',axis = 1)
x
# Out:
#        Annual_Income  Applicant_Age  Work_Experience              Occupation  \
# 0            9657655             76                0            Psychologist
# 1            9259353             37               18      Petroleum_Engineer
# 2            1509721             66                8                 Drafter
# 3            5867312             43                1    Chartered_Accountant
# 4            7223191             44                9  Air_traffic_controller
# ...              ...            ...              ...                     ...
# 99995         156398             69               10   Technology_specialist
# 99996        1900932             69               11     Mechanical_engineer
# 99997        6395936             66               11                Comedian
# 99998        4505937             52                6      Petroleum_Engineer
# 99999        4186842             58                9               Librarian
#
# ...

# %%
y = df['Loan_Default_Risk']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: Loan_Default_Risk, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
column_transform = make_column_transformer((OneHotEncoder(sparse= False),['Occupation','Residence_City','Residence_State']),remainder='passthrough')

# %%
from sklearn import tree
from sklearn.pipeline import make_pipeline

# %%
model = tree.DecisionTreeClassifier()

# %%
pipe = make_pipeline(column_transform,model)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['Occupation',
#                                                    'Residence_City',
#                                                    'Residence_State'])])),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
pipe.score(x_test,y_test)
# Out:
# 0.93075

# %%
y_pre = pipe.predict(x_test)

# %%
y_pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 3582     0
# 60498    0
# 53227    0
# 21333    1
# 3885     1
#         ..
# 60116    0
# 2415     0
# 43763    0
# 71345    0
# 77687    0
# Name: Loan_Default_Risk, Length: 20000, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pre)
# Out:
# 0.93075
